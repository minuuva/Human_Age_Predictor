# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('health.data.cleaned.csv')
df.head()
# Out:
#    Gender      Height     Weight Blood_Pressure  Cholesterol        BMI  \
# 0    Male  171.148359  86.185197        151/109   259.465814  29.423017
# 1    Male  172.946206  79.641937        134/112   263.630292  26.626847
# 2  Female  155.945488  49.167058        160/101   207.846206  20.217553
# 3  Female  169.078298  56.017921         133/94   253.283779  19.595270
# 4  Female  163.758355  73.966304        170/106   236.119899  27.582078
#
#    Blood_Glucose  Bone_Density    Vision    Hearing  ... Family_History  \
# 0     157.652848      0.132868  0.200000  58.786198  ...       Diabetes
# 1     118.507805      0.629534  0.267312  54.635270  ...  Heart Disease
# 2     143.587550      0.473487  0.248667  54.564632  ...   Hypertension
# 3     137.448581      1.184315  0.513818  79.722963  ...   Hypertension
# 4     145.328695      0.434562  0.306864  52.479469  ...       Diabetes
#
#   Cognitive_Function Mental_Health     Sleep    Stress Pollution Sun_Exposure  \
# ...

# %%
for column in df.select_dtypes(exclude = 'object'):
    sns.boxplot(y = df[col], color = 'grey')
    plt.show()

# %%
for col in df.select_dtypes(exclude = 'object'):
    sns.histplot(x = df[col], bins = 50, kde = True, color = 'skyblue')
    plt.show()

# %%
df['Income'].value_counts().plot(kind = 'pie', autopct = '%.1f')
plt.ylabel(None)
plt.show()

# %%
for col in df.select_dtypes(include = 'object'):
    sns.countplot(x = df[col], palette = 'vlag')
    plt.show()

# %%
plt.figure(figsize=(12,6))
sns.heatmap(df.select_dtypes(exclude= ['object']).corr(), annot = True, cmap = 'viridis', fmt = '.1f')
# Out:
# <Axes: >
